# %% [markdown]
# ##### Libraries

# %%
# Libraries

# !pip install openpyxl

import warnings as w
# No warnings will be shown in Out[#]:
w.simplefilter("ignore")

# Data Pre-Processing
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# # 1. Identify a dataset from online resources available.

# %%
# Import Data

# # - For PSV1
# DataLabels = pd.read_excel('../Akarsh Tomar/PSV1/dataset_labels(processed).xlsx', usecols = 'C:E') 
# DataGpsMpuLeft = pd.read_excel('../Akarsh Tomar/PSV1/dataset_gps_mpu_left(processed).xlsx')
# DataGpsMpuRight = pd.read_excel('../Akarsh Tomar/PSV1/dataset_gps_mpu_right(processed).xlsx')

# # - For PSV4
# DataLabels = pd.read_excel('../Akarsh Tomar/PSV4/dataset_labels(processed4).xlsx', usecols = 'C:E') 
# DataGpsMpuLeft = pd.read_excel('../Akarsh Tomar/PSV4/dataset_gps_mpu_left(processed4).xlsx')
# DataGpsMpuRight = pd.read_excel('../Akarsh Tomar/PSV4/dataset_gps_mpu_right(processed4).xlsx')

# # - For PSV7
# DataLabels = pd.read_excel('../Akarsh Tomar/PSV7/dataset_labels7.xlsx', usecols = 'C:E') 
# DataGpsMpuLeft = pd.read_excel('../Akarsh Tomar/PSV7/dataset_gps_mpu_left7.xlsx')
# DataGpsMpuRight = pd.read_excel('../Akarsh Tomar/PSV7/dataset_gps_mpu_right7.xlsx')

# %%
DataLabels.head()
# Out:
#   dirt_road cobblestone_road asphalt_road
# 0        No               No          Yes
# 1        No               No          Yes
# 2        No               No          Yes
# 3        No               No          Yes
# 4        No               No          Yes

# %%
DataGpsMpuLeft.head(2)
# Out:
#    timestamp  acc_x_dashboard  acc_y_dashboard  acc_z_dashboard  \
# 0   0.000000         0.487328         0.490433         0.358081
# 1   0.000008         0.496368         0.514151         0.391057
#
#    acc_x_above_suspension  acc_y_above_suspension  acc_z_above_suspension  \
# 0                0.438210                0.484467                0.514831
# 1                0.452798                0.494970                0.489227
#
#    acc_x_below_suspension  acc_y_below_suspension  acc_z_below_suspension  \
# 0                0.488972                0.480876                0.462162
# 1                0.486909                0.479275                0.462840
#
#    ...  mag_x_above_suspension  mag_y_above_suspension  \
# 0  ...                0.707371                0.839378
# 1  ...                0.707371                0.761658
#
#    mag_z_above_suspension  temp_dashboard  temp_above_suspension  \
# 0                0.671642        0.985876                  0.544
# 1                0.649932        0.977401                  0.524
#
#    temp_below_suspension  timestamp_gps  latitude  longitude     speed
# 0               0.094340            0.0   0.00325   0.999859  0.000405
# 1               0.113208            0.0   0.00325   0.999859  0.000405
#
# [2 rows x 32 columns]

# %% [markdown]
# ### Data Details
# Features - 32 to be converted to 33
# Target feature - 1 Type of road added from DataLabel into both gpsmpuleft and gpsmpuright

# %%
RoadType = DataLabels.dirt_road + DataLabels.cobblestone_road + DataLabels.asphalt_road
RoadType[:5]
# Out:
# 0    NoNoYes
# 1    NoNoYes
# 2    NoNoYes
# 3    NoNoYes
# 4    NoNoYes
# dtype: object

# %%
for i in range(len(RoadType)):
    if RoadType[i] == "NoNoYes": RoadType[i] = "Asphalt"
    elif RoadType[i] == "NoYesNo": RoadType[i] = "Cobblestone"
    if RoadType[i] == "YesNoNo": RoadType[i] = "Dirt"
set(RoadType)
# Out:
# {'Asphalt', 'Cobblestone', 'Dirt'}

# %%
DataGpsMpuLeft['RoadType'], DataGpsMpuRight['RoadType'] = RoadType, RoadType
# del RoadType
DataGpsMpuLeft.head(2)
# Out:
#    timestamp  acc_x_dashboard  acc_y_dashboard  acc_z_dashboard  \
# 0   0.000000         0.487328         0.490433         0.358081
# 1   0.000008         0.496368         0.514151         0.391057
#
#    acc_x_above_suspension  acc_y_above_suspension  acc_z_above_suspension  \
# 0                0.438210                0.484467                0.514831
# 1                0.452798                0.494970                0.489227
#
#    acc_x_below_suspension  acc_y_below_suspension  acc_z_below_suspension  \
# 0                0.488972                0.480876                0.462162
# 1                0.486909                0.479275                0.462840
#
#    ...  mag_y_above_suspension  mag_z_above_suspension  temp_dashboard  \
# 0  ...                0.839378                0.671642        0.985876
# 1  ...                0.761658                0.649932        0.977401
#
#    temp_above_suspension  temp_below_suspension  timestamp_gps  latitude  \
# 0                  0.544               0.094340            0.0   0.00325
# 1                  0.524               0.113208            0.0   0.00325
#
#    longitude     speed  RoadType
# 0   0.999859  0.000405   Asphalt
# 1   0.999859  0.000405   Asphalt
#
# [2 rows x 33 columns]

# %%
DataGpsMpuRight.head(2)
# Out:
#    timestamp  acc_x_dashboard  acc_y_dashboard  acc_z_dashboard  \
# 0   0.000000         0.511980         0.469704         0.449122
# 1   0.000008         0.495902         0.472004         0.444150
#
#    acc_x_above_suspension  acc_y_above_suspension  acc_z_above_suspension  \
# 0                0.516166                0.488189                0.353849
# 1                0.512391                0.478925                0.352058
#
#    acc_x_below_suspension  acc_y_below_suspension  acc_z_below_suspension  \
# 0                0.443616                0.466013                0.501040
# 1                0.441567                0.466424                0.499115
#
#    ...  mag_y_above_suspension  mag_z_above_suspension  temp_dashboard  \
# 0  ...                0.774194                0.682713        0.965686
# 1  ...                0.756989                0.761488        0.965686
#
#    temp_above_suspension  temp_below_suspension  timestamp_gps  latitude  \
# 0               0.603448               0.045296            0.0   0.00325
# 1               0.620690               0.038328            0.0   0.00325
#
#    longitude     speed  RoadType
# 0   0.999859  0.000405   Asphalt
# 1   0.999859  0.000405   Asphalt
#
# [2 rows x 33 columns]

# %% [markdown]
# # Saving Data as Final Dataset

# %%
# # - For PSV1
# DataGpsMpuLeft.to_csv('../../Dataset/PSV1/DataGpsMpuLeft.csv')
# DataGpsMpuRight.to_csv('../../Dataset/PSV1/DataGpsMpuRight.csv')

# # - For PSV4
# DataGpsMpuLeft.to_csv('../../Dataset/PSV4/DataGpsMpuLeft.csv')
# DataGpsMpuRight.to_csv('../../Dataset/PSV4/DataGpsMpuRight.csv')

# # - For PSV7
# DataGpsMpuLeft.to_csv('../../Dataset/PSV7/DataGpsMpuLeft.csv')
# DataGpsMpuRight.to_csv('../../Dataset/PSV7/DataGpsMpuRight.csv')

# %% [markdown]
# ---
